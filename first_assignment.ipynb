# %% [markdown]
# <a href="https://colab.research.google.com/github/Joel-G-creator/my-first-ai-app/blob/main/first_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Original List of Movies
Movies = ["Now You see Me 2" , "Iron Man 2" , "The Avengers"]

print(f"3 of my favourite movies are;")
print(Movies)

#printing first and last items in the list
print("First:",Movies[0])
print("Last:", Movies[-1])

#changing list item no_2 to "The Lion King"
print()
Movies[1]="The Lion King"

#Adding a new item to end of the original list
Movies.append("To all the Boys I've Loved Before")
print()
print(f"New List:", Movies)

#closing remarks
print()
print(f"The movie I enjoyed the most was", Movies[0])
# Out:
# 3 of my favourite movies are;
# ['Now You see Me 2', 'Iron Man 2', 'The Avengers']
# First: Now You see Me 2
# Last: The Avengers
#
#
# New List: ['Now You see Me 2', 'The Lion King', 'The Avengers', "To all the Boys I've Loved Before"]
#
# The movie I enjoyed the most was Now You see Me 2
